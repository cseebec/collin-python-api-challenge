# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Import Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# I am checking the length of cities because I want to analyze at least 500 cities . . .
# so if the len of cities is less than 500 I will rerun this code 
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Before looping through the cities I am going to set up the base url
url = "http://api.openweathermap.org/data/2.5/weather?"
# Units = imperial gives the temperature in farenheit
units = "imperial"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + cities[0]).json()

# %%
#Create empty lists and initialize variables
temp = []
humid = []
cloudiness =[]
ws = []
country = []
lat = []
lon = []
found_cities =[]

# Loop through the list of cities and perform a request for data on each
# Not every city is in the Open Weather API so I am preparing for the possibility of an error
for x in range(len(cities)):
    try:
        response = requests.get(query_url + cities[x]).json()
        found_cities.append(response['name'])
        temp.append(response['main']['temp_max'])
        humid.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        ws.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        print(f"FOUND IN API: City Number {x} Name {cities[x]}")
    except KeyError:
        print(f"NOT FOUND IN API: City Number {x} Name {cities[x]}")
# Out:
# FOUND IN API: City Number 0 Name san cristobal
# FOUND IN API: City Number 1 Name lompoc
# FOUND IN API: City Number 2 Name hobart
# FOUND IN API: City Number 3 Name nikolskoye
# FOUND IN API: City Number 4 Name chuy
# NOT FOUND IN API: City Number 5 Name barentsburg
# FOUND IN API: City Number 6 Name lufilufi
# NOT FOUND IN API: City Number 7 Name khonuu
# FOUND IN API: City Number 8 Name east london
# FOUND IN API: City Number 9 Name turka
# FOUND IN API: City Number 10 Name jamestown
# FOUND IN API: City Number 11 Name new norfolk
# FOUND IN API: City Number 12 Name westport
# FOUND IN API: City Number 13 Name saint-philippe
# FOUND IN API: City Number 14 Name mayo
# FOUND IN API: City Number 15 Name yellowknife
# FOUND IN API: City Number 16 Name nyagan
# FOUND IN API: City Number 17 Name geraldton
# FOUND IN API: City Number 18 Name mahebourg
# NOT FOUND IN API: City Number 19 Name dzhusaly
# FOUND IN API: City Number 20 Name vaini
# FOUND IN API: City Number 21 Name ushuaia
# FOUND IN API: City Number 22 Name qaanaaq
# FOUND IN API: City Number 23 Name arraial do cabo
# FOUND IN API: City Number 24 Name parakou
# FOUND IN API: City Number 25 Name albany
# FOUND IN API: City Number 26 Name punta arenas
# FOUND IN API: City Number 27 Name ginda
# FOUND IN API: City Number 28 Name flinders
# FOUND IN API: City Number 29 Name rikitea
# FOUND IN API: City Number 30 Name busselton
# FOUND IN API: City Number 31 Name hithadhoo
# FOUND IN API: City Number 32 Name coihaique
# FOUND IN API: City Number 33 Name kenai
# FOUND IN API: City Number 34 Name carnarvon
# FOUND IN API: City Number 35 Name castro
# FOUND IN API: City Number 36 Name buraydah
# FOUND IN API: City Number 37 Name kapaa
# FOUND IN API: City Number 38 Name faya
# FOUND IN API: City Number 39 Name saskylakh
# FOUND IN API: City Number 40 Name areosa
# FOUND IN API: City Number 41 Name iqaluit
# FOUND IN API: City Number 42 Name douglas
# FOUND IN API: City Number 43 Name laguna
# FOUND IN API: City Number 44 Name mataura
# FOUND IN API: City Number 45 Name mar del plata
# FOUND IN API: City Number 46 Name norman wells
# NOT FOUND IN API: City Number 47 Name illoqqortoormiut
# FOUND IN API: City Number 48 Name neftcala
# FOUND IN API: City Number 49 Name leeuwarden
# FOUND IN API: City Number 50 Name bethel
# FOUND IN API: City Number 51 Name saint george
# FOUND IN API: City Number 52 Name linjiang
# FOUND IN API: City Number 53 Name avarua
# FOUND IN API: City Number 54 Name provideniya
# FOUND IN API: City Number 55 Name soyo
# FOUND IN API: City Number 56 Name aswan
# FOUND IN API: City Number 57 Name hilo
# NOT FOUND IN API: City Number 58 Name belushya guba
# FOUND IN API: City Number 59 Name cherskiy
# NOT FOUND IN API: City Number 60 Name lolua
# FOUND IN API: City Number 61 Name clyde river
# NOT FOUND IN API: City Number 62 Name taolanaro
# FOUND IN API: City Number 63 Name svetlyy
# FOUND IN API: City Number 64 Name atuona
# FOUND IN API: City Number 65 Name victoria
# FOUND IN API: City Number 66 Name guerrero
# FOUND IN API: City Number 67 Name bluff
# FOUND IN API: City Number 68 Name dikson
# NOT FOUND IN API: City Number 69 Name umzimvubu
# FOUND IN API: City Number 70 Name acri
# FOUND IN API: City Number 71 Name posadas
# FOUND IN API: City Number 72 Name puerto leguizamo
# FOUND IN API: City Number 73 Name pangnirtung
# FOUND IN API: City Number 74 Name thompson
# FOUND IN API: City Number 75 Name vardo
# FOUND IN API: City Number 76 Name poyarkovo
# NOT FOUND IN API: City Number 77 Name sorvag
# FOUND IN API: City Number 78 Name faanui
# NOT FOUND IN API: City Number 79 Name vaitupu
# FOUND IN API: City Number 80 Name rio grande
# FOUND IN API: City Number 81 Name chernyshevskiy
# FOUND IN API: City Number 82 Name kibre mengist
# FOUND IN API: City Number 83 Name kavieng
# FOUND IN API: City Number 84 Name saint-augustin
# FOUND IN API: City Number 85 Name tiksi
# FOUND IN API: City Number 86 Name guerrero negro
# FOUND IN API: City Number 87 Name bredasdorp
# FOUND IN API: City Number 88 Name wawa
# FOUND IN API: City Number 89 Name pevek
# FOUND IN API: City Number 90 Name rognan
# NOT FOUND IN API: City Number 91 Name tsihombe
# FOUND IN API: City Number 92 Name revda
# FOUND IN API: City Number 93 Name hualmay
# FOUND IN API: City Number 94 Name muscat
# FOUND IN API: City Number 95 Name leningradskiy
# FOUND IN API: City Number 96 Name gilgit
# FOUND IN API: City Number 97 Name campo maior
# NOT FOUND IN API: City Number 98 Name attawapiskat
# FOUND IN API: City Number 99 Name port alfred
# FOUND IN API: City Number 100 Name surab
# FOUND IN API: City Number 101 Name klaksvik
# FOUND IN API: City Number 102 Name severo-kurilsk
# FOUND IN API: City Number 103 Name beyneu
# NOT FOUND IN API: City Number 104 Name grand river south east
# FOUND IN API: City Number 105 Name ust-kuyga
# FOUND IN API: City Number 106 Name chokurdakh
# FOUND IN API: City Number 107 Name puerto ayora
# FOUND IN API: City Number 108 Name loding
# FOUND IN API: City Number 109 Name kholm
# FOUND IN API: City Number 110 Name wajid
# NOT FOUND IN API: City Number 111 Name cookshire
# FOUND IN API: City Number 112 Name saint-pierre
# FOUND IN API: City Number 113 Name xai-xai
# FOUND IN API: City Number 114 Name pallasovka
# FOUND IN API: City Number 115 Name cape town
# FOUND IN API: City Number 116 Name brandfort
# FOUND IN API: City Number 117 Name najran
# FOUND IN API: City Number 118 Name mityana
# FOUND IN API: City Number 119 Name kodiak
# FOUND IN API: City Number 120 Name pontevedra
# FOUND IN API: City Number 121 Name alexandria
# FOUND IN API: City Number 122 Name oxapampa
# FOUND IN API: City Number 123 Name batangafo
# FOUND IN API: City Number 124 Name fortuna
# NOT FOUND IN API: City Number 125 Name aflu
# FOUND IN API: City Number 126 Name high level
# FOUND IN API: City Number 127 Name eureka
# FOUND IN API: City Number 128 Name kuryk
# FOUND IN API: City Number 129 Name holme
# FOUND IN API: City Number 130 Name lang suan
# NOT FOUND IN API: City Number 131 Name rungata
# FOUND IN API: City Number 132 Name barcelos
# FOUND IN API: City Number 133 Name kaitangata
# FOUND IN API: City Number 134 Name yar-sale
# FOUND IN API: City Number 135 Name arlit
# FOUND IN API: City Number 136 Name tuktoyaktuk
# FOUND IN API: City Number 137 Name kiama
# FOUND IN API: City Number 138 Name codrington
# FOUND IN API: City Number 139 Name bafra
# FOUND IN API: City Number 140 Name kieta
# FOUND IN API: City Number 141 Name baykit
# FOUND IN API: City Number 142 Name vilhena
# FOUND IN API: City Number 143 Name huarmey
# FOUND IN API: City Number 144 Name namibe
# NOT FOUND IN API: City Number 145 Name yomitan
# FOUND IN API: City Number 146 Name tromso
# FOUND IN API: City Number 147 Name portland
# FOUND IN API: City Number 148 Name labuhan
# FOUND IN API: City Number 149 Name ancud
# FOUND IN API: City Number 150 Name chengde
# FOUND IN API: City Number 151 Name shimoda
# FOUND IN API: City Number 152 Name mogadishu
# FOUND IN API: City Number 153 Name ishigaki
# FOUND IN API: City Number 154 Name longyearbyen
# NOT FOUND IN API: City Number 155 Name samusu
# FOUND IN API: City Number 156 Name kharopon
# FOUND IN API: City Number 157 Name hovd
# FOUND IN API: City Number 158 Name lebu
# FOUND IN API: City Number 159 Name bad bevensen
# FOUND IN API: City Number 160 Name torbay
# FOUND IN API: City Number 161 Name hami
# FOUND IN API: City Number 162 Name ngunguru
# FOUND IN API: City Number 163 Name tanout
# FOUND IN API: City Number 164 Name marquette
# FOUND IN API: City Number 165 Name pangody
# FOUND IN API: City Number 166 Name esso
# FOUND IN API: City Number 167 Name kizhinga
# NOT FOUND IN API: City Number 168 Name warqla
# FOUND IN API: City Number 169 Name san joaquin
# FOUND IN API: City Number 170 Name airai
# FOUND IN API: City Number 171 Name nelson bay
# FOUND IN API: City Number 172 Name shetpe
# FOUND IN API: City Number 173 Name apollonia
# FOUND IN API: City Number 174 Name belmonte
# FOUND IN API: City Number 175 Name mount gambier
# FOUND IN API: City Number 176 Name biloela
# FOUND IN API: City Number 177 Name nuuk
# FOUND IN API: City Number 178 Name catamarca
# FOUND IN API: City Number 179 Name porto novo
# FOUND IN API: City Number 180 Name prince rupert
# FOUND IN API: City Number 181 Name bengkulu
# FOUND IN API: City Number 182 Name puerto del rosario
# FOUND IN API: City Number 183 Name vila velha
# FOUND IN API: City Number 184 Name mehamn
# NOT FOUND IN API: City Number 185 Name marcona
# FOUND IN API: City Number 186 Name macaubas
# FOUND IN API: City Number 187 Name saldanha
# FOUND IN API: City Number 188 Name popondetta
# FOUND IN API: City Number 189 Name atambua
# FOUND IN API: City Number 190 Name liwale
# FOUND IN API: City Number 191 Name nome
# FOUND IN API: City Number 192 Name rawson
# FOUND IN API: City Number 193 Name toamasina
# FOUND IN API: City Number 194 Name puerto quijarro
# FOUND IN API: City Number 195 Name pakdasht
# FOUND IN API: City Number 196 Name chalon-sur-saone
# FOUND IN API: City Number 197 Name mount isa
# FOUND IN API: City Number 198 Name ribeira grande
# FOUND IN API: City Number 199 Name hermanus
# FOUND IN API: City Number 200 Name ponta do sol
# FOUND IN API: City Number 201 Name cidreira
# FOUND IN API: City Number 202 Name vredendal
# FOUND IN API: City Number 203 Name sao felix do xingu
# FOUND IN API: City Number 204 Name zhuhai
# FOUND IN API: City Number 205 Name luderitz
# FOUND IN API: City Number 206 Name dingle
# FOUND IN API: City Number 207 Name husavik
# FOUND IN API: City Number 208 Name mandurah
# FOUND IN API: City Number 209 Name machico
# FOUND IN API: City Number 210 Name gamba
# FOUND IN API: City Number 211 Name khatanga
# FOUND IN API: City Number 212 Name deniliquin
# FOUND IN API: City Number 213 Name sao jose da coroa grande
# FOUND IN API: City Number 214 Name butaritari
# FOUND IN API: City Number 215 Name georgetown
# FOUND IN API: City Number 216 Name kloulklubed
# FOUND IN API: City Number 217 Name kiruna
# FOUND IN API: City Number 218 Name fukue
# FOUND IN API: City Number 219 Name alofi
# NOT FOUND IN API: City Number 220 Name mutsamudu
# NOT FOUND IN API: City Number 221 Name carikar
# FOUND IN API: City Number 222 Name esperance
# FOUND IN API: City Number 223 Name bima
# FOUND IN API: City Number 224 Name bayangol
# FOUND IN API: City Number 225 Name vammala
# FOUND IN API: City Number 226 Name alice
# NOT FOUND IN API: City Number 227 Name tunduru
# NOT FOUND IN API: City Number 228 Name katsiveli
# FOUND IN API: City Number 229 Name oktyabrskoye
# FOUND IN API: City Number 230 Name sitka
# FOUND IN API: City Number 231 Name flin flon
# FOUND IN API: City Number 232 Name cabedelo
# NOT FOUND IN API: City Number 233 Name port-de-paix
# FOUND IN API: City Number 234 Name mega
# FOUND IN API: City Number 235 Name kahului
# FOUND IN API: City Number 236 Name posse
# FOUND IN API: City Number 237 Name bedford
# FOUND IN API: City Number 238 Name shibganj
# FOUND IN API: City Number 239 Name hofn
# FOUND IN API: City Number 240 Name kautokeino
# FOUND IN API: City Number 241 Name mushie
# FOUND IN API: City Number 242 Name sao raimundo nonato
# FOUND IN API: City Number 243 Name srandakan
# FOUND IN API: City Number 244 Name charters towers
# FOUND IN API: City Number 245 Name batemans bay
# FOUND IN API: City Number 246 Name tura
# FOUND IN API: City Number 247 Name yumen
# FOUND IN API: City Number 248 Name pemangkat
# NOT FOUND IN API: City Number 249 Name gurskoye
# FOUND IN API: City Number 250 Name penzance
# FOUND IN API: City Number 251 Name port hardy
# FOUND IN API: City Number 252 Name kurilsk
# FOUND IN API: City Number 253 Name nova venecia
# FOUND IN API: City Number 254 Name costeiu
# FOUND IN API: City Number 255 Name shakawe
# FOUND IN API: City Number 256 Name constitucion
# FOUND IN API: City Number 257 Name frankfort
# FOUND IN API: City Number 258 Name kwekwe
# FOUND IN API: City Number 259 Name tasiilaq
# FOUND IN API: City Number 260 Name gaogou
# FOUND IN API: City Number 261 Name inndyr
# FOUND IN API: City Number 262 Name deoband
# NOT FOUND IN API: City Number 263 Name toliary
# FOUND IN API: City Number 264 Name sioux lookout
# FOUND IN API: City Number 265 Name fairbanks
# FOUND IN API: City Number 266 Name wageningen
# FOUND IN API: City Number 267 Name akyab
# NOT FOUND IN API: City Number 268 Name nizhneyansk
# FOUND IN API: City Number 269 Name robertsport
# FOUND IN API: City Number 270 Name smithers
# FOUND IN API: City Number 271 Name honiara
# FOUND IN API: City Number 272 Name vaitape
# FOUND IN API: City Number 273 Name amapa
# FOUND IN API: City Number 274 Name tazovskiy
# FOUND IN API: City Number 275 Name baruun-urt
# FOUND IN API: City Number 276 Name meulaboh
# FOUND IN API: City Number 277 Name hamilton
# FOUND IN API: City Number 278 Name brigantine
# NOT FOUND IN API: City Number 279 Name barbar
# FOUND IN API: City Number 280 Name grand gaube
# FOUND IN API: City Number 281 Name itoman
# FOUND IN API: City Number 282 Name college
# FOUND IN API: City Number 283 Name namatanai
# FOUND IN API: City Number 284 Name meridian
# FOUND IN API: City Number 285 Name werda
# FOUND IN API: City Number 286 Name katsuura
# NOT FOUND IN API: City Number 287 Name kazalinsk
# NOT FOUND IN API: City Number 288 Name tawkar
# FOUND IN API: City Number 289 Name sorland
# FOUND IN API: City Number 290 Name necochea
# FOUND IN API: City Number 291 Name raudeberg
# FOUND IN API: City Number 292 Name paamiut
# FOUND IN API: City Number 293 Name upernavik
# FOUND IN API: City Number 294 Name mountain home
# FOUND IN API: City Number 295 Name zeya
# FOUND IN API: City Number 296 Name camacha
# FOUND IN API: City Number 297 Name dafeng
# FOUND IN API: City Number 298 Name victoria point
# FOUND IN API: City Number 299 Name lima
# FOUND IN API: City Number 300 Name ponta delgada
# FOUND IN API: City Number 301 Name tateyama
# FOUND IN API: City Number 302 Name eyl
# FOUND IN API: City Number 303 Name ruyigi
# FOUND IN API: City Number 304 Name salalah
# FOUND IN API: City Number 305 Name erdenet
# FOUND IN API: City Number 306 Name saint-leu
# FOUND IN API: City Number 307 Name yhu
# NOT FOUND IN API: City Number 308 Name formoso do araguaia
# FOUND IN API: City Number 309 Name lavrentiya
# FOUND IN API: City Number 310 Name kachiry
# FOUND IN API: City Number 311 Name bilibino
# FOUND IN API: City Number 312 Name mahajanga
# FOUND IN API: City Number 313 Name axim
# FOUND IN API: City Number 314 Name nioro
# NOT FOUND IN API: City Number 315 Name sentyabrskiy
# FOUND IN API: City Number 316 Name lodja
# FOUND IN API: City Number 317 Name mamburao
# FOUND IN API: City Number 318 Name udachnyy
# NOT FOUND IN API: City Number 319 Name yirol
# FOUND IN API: City Number 320 Name pervomayskoye
# FOUND IN API: City Number 321 Name lorengau
# FOUND IN API: City Number 322 Name birao
# FOUND IN API: City Number 323 Name sarangani
# FOUND IN API: City Number 324 Name naze
# FOUND IN API: City Number 325 Name jatiroto
# FOUND IN API: City Number 326 Name ocean springs
# FOUND IN API: City Number 327 Name general pico
# FOUND IN API: City Number 328 Name yerbogachen
# NOT FOUND IN API: City Number 329 Name falealupo
# NOT FOUND IN API: City Number 330 Name tasbuget
# FOUND IN API: City Number 331 Name manggar
# NOT FOUND IN API: City Number 332 Name inderborskiy
# FOUND IN API: City Number 333 Name niquero
# FOUND IN API: City Number 334 Name kirakira
# FOUND IN API: City Number 335 Name karratha
# FOUND IN API: City Number 336 Name tahta
# FOUND IN API: City Number 337 Name erenhot
# FOUND IN API: City Number 338 Name winslow
# FOUND IN API: City Number 339 Name noumea
# FOUND IN API: City Number 340 Name orange cove
# FOUND IN API: City Number 341 Name port hawkesbury
# FOUND IN API: City Number 342 Name taoudenni
# FOUND IN API: City Number 343 Name huicheng
# FOUND IN API: City Number 344 Name dukat
# FOUND IN API: City Number 345 Name matagami
# FOUND IN API: City Number 346 Name touros
# FOUND IN API: City Number 347 Name carauari
# FOUND IN API: City Number 348 Name puerto baquerizo moreno
# FOUND IN API: City Number 349 Name kaeo
# NOT FOUND IN API: City Number 350 Name saleaula
# FOUND IN API: City Number 351 Name road town
# FOUND IN API: City Number 352 Name bambous virieux
# NOT FOUND IN API: City Number 353 Name mys shmidta
# FOUND IN API: City Number 354 Name gat
# FOUND IN API: City Number 355 Name jesenik
# FOUND IN API: City Number 356 Name bambanglipuro
# FOUND IN API: City Number 357 Name oum hadjer
# FOUND IN API: City Number 358 Name cabanas
# FOUND IN API: City Number 359 Name lar
# FOUND IN API: City Number 360 Name ilulissat
# FOUND IN API: City Number 361 Name acajutla
# FOUND IN API: City Number 362 Name pandan
# FOUND IN API: City Number 363 Name cukai
# FOUND IN API: City Number 364 Name pangkalanbuun
# FOUND IN API: City Number 365 Name camopi
# FOUND IN API: City Number 366 Name mwinilunga
# FOUND IN API: City Number 367 Name cabo san lucas
# FOUND IN API: City Number 368 Name berlevag
# FOUND IN API: City Number 369 Name trat
# FOUND IN API: City Number 370 Name la paz
# FOUND IN API: City Number 371 Name mutoko
# FOUND IN API: City Number 372 Name damietta
# FOUND IN API: City Number 373 Name shar
# FOUND IN API: City Number 374 Name oranjestad
# FOUND IN API: City Number 375 Name kapit
# FOUND IN API: City Number 376 Name el carmen
# FOUND IN API: City Number 377 Name maua
# FOUND IN API: City Number 378 Name san quintin
# FOUND IN API: City Number 379 Name masterton
# FOUND IN API: City Number 380 Name beaumont
# FOUND IN API: City Number 381 Name caravelas
# FOUND IN API: City Number 382 Name isabela
# FOUND IN API: City Number 383 Name half moon bay
# FOUND IN API: City Number 384 Name port moresby
# FOUND IN API: City Number 385 Name misratah
# FOUND IN API: City Number 386 Name juneau
# FOUND IN API: City Number 387 Name jalu
# FOUND IN API: City Number 388 Name cayenne
# FOUND IN API: City Number 389 Name nurota
# FOUND IN API: City Number 390 Name nanortalik
# FOUND IN API: City Number 391 Name chimbote
# FOUND IN API: City Number 392 Name quelimane
# FOUND IN API: City Number 393 Name mgachi
# FOUND IN API: City Number 394 Name palafrugell
# FOUND IN API: City Number 395 Name lakatoro
# FOUND IN API: City Number 396 Name jawhar
# FOUND IN API: City Number 397 Name lixourion
# FOUND IN API: City Number 398 Name barrow
# FOUND IN API: City Number 399 Name anadyr
# FOUND IN API: City Number 400 Name manyana
# NOT FOUND IN API: City Number 401 Name amderma
# FOUND IN API: City Number 402 Name halifax
# FOUND IN API: City Number 403 Name havre
# FOUND IN API: City Number 404 Name kama
# FOUND IN API: City Number 405 Name margate
# FOUND IN API: City Number 406 Name bolshaya martynovka
# FOUND IN API: City Number 407 Name palmer
# FOUND IN API: City Number 408 Name abu kamal
# FOUND IN API: City Number 409 Name quang ngai
# FOUND IN API: City Number 410 Name port hedland
# FOUND IN API: City Number 411 Name general roca
# FOUND IN API: City Number 412 Name sao filipe
# FOUND IN API: City Number 413 Name taunggyi
# FOUND IN API: City Number 414 Name nantucket
# FOUND IN API: City Number 415 Name sola
# FOUND IN API: City Number 416 Name channel-port aux basques
# FOUND IN API: City Number 417 Name auki
# FOUND IN API: City Number 418 Name dunedin
# FOUND IN API: City Number 419 Name mitsamiouli
# FOUND IN API: City Number 420 Name grindavik
# FOUND IN API: City Number 421 Name kalmunai
# FOUND IN API: City Number 422 Name samarai
# FOUND IN API: City Number 423 Name brae
# FOUND IN API: City Number 424 Name yulara
# FOUND IN API: City Number 425 Name sao gabriel da cachoeira
# FOUND IN API: City Number 426 Name vuktyl
# FOUND IN API: City Number 427 Name alta floresta
# FOUND IN API: City Number 428 Name kruisfontein
# FOUND IN API: City Number 429 Name padang
# FOUND IN API: City Number 430 Name talnakh
# FOUND IN API: City Number 431 Name eyemouth
# FOUND IN API: City Number 432 Name balkhash
# FOUND IN API: City Number 433 Name bubaque
# FOUND IN API: City Number 434 Name salina
# FOUND IN API: City Number 435 Name maragogi
# FOUND IN API: City Number 436 Name mount hagen
# FOUND IN API: City Number 437 Name terrace bay
# FOUND IN API: City Number 438 Name comodoro rivadavia
# FOUND IN API: City Number 439 Name bonfim
# FOUND IN API: City Number 440 Name mafeteng
# FOUND IN API: City Number 441 Name adrar
# FOUND IN API: City Number 442 Name porangatu
# FOUND IN API: City Number 443 Name vila franca do campo
# FOUND IN API: City Number 444 Name nyurba
# FOUND IN API: City Number 445 Name puksoozero
# FOUND IN API: City Number 446 Name batticaloa
# FOUND IN API: City Number 447 Name chiang khong
# FOUND IN API: City Number 448 Name praia da vitoria
# FOUND IN API: City Number 449 Name ulefoss
# FOUND IN API: City Number 450 Name tuatapere
# FOUND IN API: City Number 451 Name port keats
# FOUND IN API: City Number 452 Name san vicente
# FOUND IN API: City Number 453 Name nishihara
# FOUND IN API: City Number 454 Name blythe
# FOUND IN API: City Number 455 Name mackay
# FOUND IN API: City Number 456 Name ukiah
# FOUND IN API: City Number 457 Name janow lubelski
# FOUND IN API: City Number 458 Name mortka
# FOUND IN API: City Number 459 Name balkanabat
# FOUND IN API: City Number 460 Name teahupoo
# FOUND IN API: City Number 461 Name tabuk
# NOT FOUND IN API: City Number 462 Name paradwip
# FOUND IN API: City Number 463 Name pacific grove
# FOUND IN API: City Number 464 Name pudozh
# FOUND IN API: City Number 465 Name dudinka
# FOUND IN API: City Number 466 Name vao
# FOUND IN API: City Number 467 Name lagoa
# FOUND IN API: City Number 468 Name havre-saint-pierre
# FOUND IN API: City Number 469 Name kisangani
# FOUND IN API: City Number 470 Name vostok
# FOUND IN API: City Number 471 Name bogande
# FOUND IN API: City Number 472 Name log
# FOUND IN API: City Number 473 Name malakwal
# FOUND IN API: City Number 474 Name olafsvik
# FOUND IN API: City Number 475 Name oranjemund
# FOUND IN API: City Number 476 Name buckeye
# FOUND IN API: City Number 477 Name byron bay
# FOUND IN API: City Number 478 Name la macarena
# NOT FOUND IN API: City Number 479 Name yialos
# FOUND IN API: City Number 480 Name bandundu
# FOUND IN API: City Number 481 Name russkaya polyana
# FOUND IN API: City Number 482 Name danane
# FOUND IN API: City Number 483 Name te anau
# FOUND IN API: City Number 484 Name richards bay
# FOUND IN API: City Number 485 Name tokur
# FOUND IN API: City Number 486 Name quatre cocos
# FOUND IN API: City Number 487 Name puro
# FOUND IN API: City Number 488 Name vrangel
# FOUND IN API: City Number 489 Name zhigansk
# FOUND IN API: City Number 490 Name lazaro cardenas
# FOUND IN API: City Number 491 Name bandarbeyla
# FOUND IN API: City Number 492 Name fort dodge
# FOUND IN API: City Number 493 Name nemuro
# FOUND IN API: City Number 494 Name sambava
# FOUND IN API: City Number 495 Name keelung
# FOUND IN API: City Number 496 Name lebyazhye
# FOUND IN API: City Number 497 Name yalutorovsk
# FOUND IN API: City Number 498 Name tautira
# FOUND IN API: City Number 499 Name conakry
# FOUND IN API: City Number 500 Name hasaki
# FOUND IN API: City Number 501 Name timmins
# FOUND IN API: City Number 502 Name ballitoville
# FOUND IN API: City Number 503 Name canete
# FOUND IN API: City Number 504 Name kemin
# FOUND IN API: City Number 505 Name benguela
# NOT FOUND IN API: City Number 506 Name hihifo
# FOUND IN API: City Number 507 Name upata
# NOT FOUND IN API: City Number 508 Name halalo
# FOUND IN API: City Number 509 Name chara
# FOUND IN API: City Number 510 Name ziro
# FOUND IN API: City Number 511 Name bendigo
# FOUND IN API: City Number 512 Name deputatskiy
# FOUND IN API: City Number 513 Name moron
# FOUND IN API: City Number 514 Name yeppoon
# FOUND IN API: City Number 515 Name thunder bay
# FOUND IN API: City Number 516 Name gbadolite
# FOUND IN API: City Number 517 Name coquimbo
# FOUND IN API: City Number 518 Name huilong
# FOUND IN API: City Number 519 Name bataipora
# NOT FOUND IN API: City Number 520 Name bargal
# FOUND IN API: City Number 521 Name devonport
# FOUND IN API: City Number 522 Name nshamba
# FOUND IN API: City Number 523 Name haines junction
# FOUND IN API: City Number 524 Name snasa
# NOT FOUND IN API: City Number 525 Name utiroa
# FOUND IN API: City Number 526 Name davila
# FOUND IN API: City Number 527 Name yaring
# FOUND IN API: City Number 528 Name port blair
# FOUND IN API: City Number 529 Name turkistan
# FOUND IN API: City Number 530 Name nadapuram
# NOT FOUND IN API: City Number 531 Name lemesos
# FOUND IN API: City Number 532 Name marang
# FOUND IN API: City Number 533 Name kathu
# FOUND IN API: City Number 534 Name kingaroy
# FOUND IN API: City Number 535 Name tecolutla
# FOUND IN API: City Number 536 Name bereda
# FOUND IN API: City Number 537 Name zemio
# FOUND IN API: City Number 538 Name gravdal
# FOUND IN API: City Number 539 Name lyngdal
# FOUND IN API: City Number 540 Name maniitsoq
# FOUND IN API: City Number 541 Name north platte
# FOUND IN API: City Number 542 Name maumere
# FOUND IN API: City Number 543 Name requena
# FOUND IN API: City Number 544 Name tabas
# NOT FOUND IN API: City Number 545 Name hendijan
# FOUND IN API: City Number 546 Name upala
# FOUND IN API: City Number 547 Name honda
# FOUND IN API: City Number 548 Name papayal
# FOUND IN API: City Number 549 Name makakilo city
# FOUND IN API: City Number 550 Name juruti
# FOUND IN API: City Number 551 Name pietarsaari
# FOUND IN API: City Number 552 Name chivay
# FOUND IN API: City Number 553 Name valparai
# FOUND IN API: City Number 554 Name pimentel
# FOUND IN API: City Number 555 Name ust-donetskiy
# FOUND IN API: City Number 556 Name isangel
# FOUND IN API: City Number 557 Name kuznechnoye
# FOUND IN API: City Number 558 Name chaumont
# FOUND IN API: City Number 559 Name sorkjosen
# FOUND IN API: City Number 560 Name tammisaari
# FOUND IN API: City Number 561 Name ulladulla
# FOUND IN API: City Number 562 Name dongying
# FOUND IN API: City Number 563 Name rudsar
# FOUND IN API: City Number 564 Name falun
# FOUND IN API: City Number 565 Name port elizabeth
# FOUND IN API: City Number 566 Name lata
# FOUND IN API: City Number 567 Name marigot
# FOUND IN API: City Number 568 Name zhangye
# FOUND IN API: City Number 569 Name ygatimi
# FOUND IN API: City Number 570 Name lianran
# FOUND IN API: City Number 571 Name nouakchott
# FOUND IN API: City Number 572 Name port shepstone
# FOUND IN API: City Number 573 Name puerto narino
# FOUND IN API: City Number 574 Name muros
# FOUND IN API: City Number 575 Name aklavik
# FOUND IN API: City Number 576 Name agirish
# FOUND IN API: City Number 577 Name los llanos de aridane
# FOUND IN API: City Number 578 Name namie
# FOUND IN API: City Number 579 Name prudentopolis
# FOUND IN API: City Number 580 Name bilma
# FOUND IN API: City Number 581 Name fayaoue
# FOUND IN API: City Number 582 Name araceli
# FOUND IN API: City Number 583 Name gazanjyk
# NOT FOUND IN API: City Number 584 Name wahran
# FOUND IN API: City Number 585 Name okhotsk
# NOT FOUND IN API: City Number 586 Name riaba
# NOT FOUND IN API: City Number 587 Name safwah
# FOUND IN API: City Number 588 Name henties bay
# FOUND IN API: City Number 589 Name mineiros
# FOUND IN API: City Number 590 Name zaranj
# FOUND IN API: City Number 591 Name shelburne
# FOUND IN API: City Number 592 Name goma
# FOUND IN API: City Number 593 Name casper
# FOUND IN API: City Number 594 Name balingasay
# FOUND IN API: City Number 595 Name seoul
# FOUND IN API: City Number 596 Name ambilobe
# NOT FOUND IN API: City Number 597 Name azimur
# FOUND IN API: City Number 598 Name tessalit
# NOT FOUND IN API: City Number 599 Name karamken
# FOUND IN API: City Number 600 Name ogulin
# FOUND IN API: City Number 601 Name alice springs
# FOUND IN API: City Number 602 Name fort nelson
# FOUND IN API: City Number 603 Name pascagoula
# FOUND IN API: City Number 604 Name bolu
# FOUND IN API: City Number 605 Name barstow
# FOUND IN API: City Number 606 Name moussoro
# FOUND IN API: City Number 607 Name beringovskiy
# FOUND IN API: City Number 608 Name port macquarie
# FOUND IN API: City Number 609 Name okha
# FOUND IN API: City Number 610 Name ostrovnoy
# FOUND IN API: City Number 611 Name visnes
# FOUND IN API: City Number 612 Name koluszki
# FOUND IN API: City Number 613 Name curuguaty
# FOUND IN API: City Number 614 Name sur
# FOUND IN API: City Number 615 Name bairiki
# FOUND IN API: City Number 616 Name ladysmith
# NOT FOUND IN API: City Number 617 Name ngukurr
# FOUND IN API: City Number 618 Name carutapera
# FOUND IN API: City Number 619 Name gostyn
# FOUND IN API: City Number 620 Name perleberg
# FOUND IN API: City Number 621 Name maloy
# FOUND IN API: City Number 622 Name pitimbu
# FOUND IN API: City Number 623 Name tingo maria
# FOUND IN API: City Number 624 Name chiradzulu
# FOUND IN API: City Number 625 Name yichang
# FOUND IN API: City Number 626 Name avera
# FOUND IN API: City Number 627 Name griffith
# FOUND IN API: City Number 628 Name desa
# FOUND IN API: City Number 629 Name queenstown
# FOUND IN API: City Number 630 Name chaiyaphum

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#This is to check that the data has at least 500 cities
print(len(found_cities))

# Create an index list
index_list = []
for x in range(len(found_cities)):
    index_list = []
# Out:
# 577

# %%
# Create dataframe with the data read in from the API
city_weather_df = pd.DataFrame(index_list)
city_weather_df["City"] = found_cities
city_weather_df["Latitude"] = lat
city_weather_df["Longitude"] = lon
city_weather_df["Country"] = country
city_weather_df["Temperature (F)"] = temp
city_weather_df["Humidity %"] = humid
city_weather_df["Cloudiness %"] = cloudiness
city_weather_df["Wind Speed (mph)"] = ws

# Write dataframe to a csv file 
city_weather_df.to_csv("output_data/cities.csv", header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Remove all rows in dataframe where Humididty is over 100%
city_weather_df = city_weather_df.loc[city_weather_df["Humidity %"]<100,:]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_weather_df["Latitude"], city_weather_df["Temperature (F)"], marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (F)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Save as png
plt.savefig("output_data/Lat_vs_MaxTemp.png")
plt.show()

# %% [markdown]
# The scatterplot above shows the relationship between Maximum Temperature in farenheit and the Latitude of over 500 cities around the world. It shows the relationship that anyone would expect which parabolic relationship where cities closer to a latitude of 0 (the equator) are hotter and cities further from the equator are colder.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather_df["Latitude"], city_weather_df["Humidity %"], marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
# Incorporate the other graph properties
plt.title("City Latitude vs Humidity %")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

#Save as png
plt.savefig("output_data/Lat_vs_Humidity%.png")
plt.show()

# %% [markdown]
# The scatterplot above shows the relationship between latitude and humidity % of over 500 cities around the world. There is no relationship between the variables in the scatterplot so I can not conclude there is a relationship between City Latitude and Humidity %

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_weather_df["Latitude"], city_weather_df["Cloudiness %"], marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness %")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

#Save as png
plt.savefig("output_data/Lat_vs_Cloudiness%.png")
plt.show()

# %% [markdown]
# The Scatterplot above plots City Latitude vs Cloudiness % for over 500 cities around the world. There is no relationship shown in the scatterplot, so I can not conclude any relationship between City Latitude and Cloudiness %.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_weather_df["Latitude"], city_weather_df["Wind Speed (mph)"], marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (mph)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#Save as png
plt.savefig("output_data/Lat_vs_WindSpeed(mph).png")
plt.show()

# %% [markdown]
# The Scatterplot above plots City Latitude vs Wind Speed (mph) for over 500 cities around the world. There is no relationship evident by looking at the scatterplot so I cannot conclude that there is a relationship between City Latitude and Wind Speed in mph.

# %% [markdown]
# ## Linear Regression

# %%
# First I have to spilt the 2 dataframes one for the Northern Hemisphere and one for the Southern Hemisphere
northern_df = city_weather_df.loc[city_weather_df["Latitude"]>=0,:]
southern_df = city_weather_df.loc[city_weather_df["Latitude"]<0,:]
print(len(city_weather_df))
print(len(northern_df))
print(len(southern_df))
# Out:
# 574
# 378
# 196

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = northern_df['Latitude']
y_values = northern_df['Temperature (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(4,42),fontsize=12,color="red")
plt.title(" Northern Hemisphere City Latitude vs Max Temperature (F)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Northern_Lat_vs_MaxTemp.png")

correlation = st.pearsonr(northern_df['Latitude'], northern_df['Temperature (F)'])
print(f"The correlation coefficient between Latitude and Max Temperature (F) is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Max Temperature (F) is -0.63

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = southern_df['Latitude']
y_values = southern_df['Temperature (F)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,85),fontsize=12,color="red")

plt.title("Southern Hemisphere City Latitude vs Max Temperature (F)")

plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Southern_Lat_vs_MaxTemp.png")

correlation = st.pearsonr(southern_df['Latitude'], southern_df['Temperature (F)'])

print(f"The correlation coefficient between Latitude and Max Temperature (F) is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Max Temperature (F) is 0.71

# %% [markdown]
# The Scatterplot for both the Northern Hemisphere and the Southern Hemishpere both show the same trend which is that as the Latitude of Cities gets closer to 0 (the equator) the temperature rises. This correlation is evident by the fact that the scatterplots have correlation coefficients of -0.63 and 0.71 which are both relatively strong correlations.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = northern_df['Latitude']
y_values = northern_df['Humidity %']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(52,10),fontsize=12,color="red")
plt.title("Northern Hemisphere City Latitude vs Humidity %")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Northern_Lat_vs_Humidity.png")

correlation = st.pearsonr(northern_df['Latitude'], northern_df['Humidity %'])
print(f"The correlation coefficient between Latitude and Humidity % is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Humidity % is -0.02

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = southern_df['Latitude']
y_values = southern_df['Humidity %']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-53,21),fontsize=12,color="red")
plt.title("Southern Hemisphere City Latitude vs Humidity %")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Southern_Lat_vs_Humidity.png")

correlation = st.pearsonr(southern_df['Latitude'], southern_df['Humidity %'])
print(f"The correlation coefficient between Latitude and Humidity % is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Humidity % is 0.14

# %% [markdown]
# The Scatterplots for the Northern and the Southern Hemishperes both show that there is no correlation between a City's Latitude and the Humidity % of that city. This is evident by the fact that the correlation coefficients for the Northern and Southern Hemisphers for Latitude vs Humidity % are -0.02 and -0.14 respectively. Both these correlation coefficients indicate an extremely weak correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = northern_df['Latitude']
y_values = northern_df['Cloudiness %']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-1,-1),fontsize=12,color="red")
plt.title("Northern Hemisphere City Latitude vs Cloudiness %")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Northern_Lat_vs_Cloudiness.png")

correlation = st.pearsonr(northern_df['Latitude'], northern_df['Cloudiness %'])
print(f"The correlation coefficient between Latitude and Cloudiness % is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Cloudiness % is -0.13

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = southern_df['Latitude']
y_values = southern_df['Cloudiness %']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-54,88),fontsize=12,color="red")
plt.title("Southern Hemisphere City Latitude vs Cloudiness %")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Southern_Lat_vs_Cloudiness.png")

correlation = st.pearsonr(southern_df['Latitude'], southern_df['Cloudiness %'])
print(f"The correlation coefficient between Latitude and Cloudiness % is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Cloudiness % is -0.0

# %% [markdown]
# The Scatterplots for the Northern and the Southern Hemishperes both show that there is no correlation between a City's Latitude and the Cloudiness % in that city. This is evident by the fact that the correlation coefficients for the Northern and Southern Hemisphers for Latitude vs Cloudiness % are -0.13 and -0.0 which are both extremely work correlations.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = northern_df['Latitude']
y_values = northern_df['Wind Speed (mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,24),fontsize=12,color="red")
plt.title("Northern Hemisphere City Latitude vs Wind Speed (mph)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Northern_Lat_vs_WindSpeed.png")

correlation = st.pearsonr(northern_df['Latitude'], northern_df['Wind Speed (mph)'])
print(f"The correlation coefficient between Latitude and Wind Speed is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Wind Speed is -0.09

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = southern_df['Latitude']
y_values = southern_df['Wind Speed (mph)']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", alpha =0.7)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,32),fontsize=12,color="red")
plt.title("Southern Hemisphere City Latitude vs Wind Speed (mph)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Southern_Lat_vs_WindSpeed.png")

correlation = st.pearsonr(southern_df['Latitude'], southern_df['Wind Speed (mph)'])
print(f"The correlation coefficient between Latitude and Wind Speed is {round(correlation[0],2)}")

plt.show()
# Out:
# The correlation coefficient between Latitude and Wind Speed is -0.29

# %% [markdown]
# The Scatterplots for the Northern and the Southern Hemishperes both show that there is no correlation between a City's Latitude and the Wind Speed (mph) in that city. This is evident by the fact that the correlation coefficients for the Northern and Southern Hemispheres for Latitude vs Wind Speed (mph) are -0.09 and -0.29 which are both extremely weak correlations.
